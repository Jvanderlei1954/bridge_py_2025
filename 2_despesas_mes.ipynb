# %%
#===============================================================================
# Trabalhando orçamento doméstico e provisionamento para feira e supermercado
#===============================================================================

# %%
# Montando dicionário com provisionamento e despesas
####################################################
# Total geral das receitas recebidas (R$ 370,00)
####################################################

# Indice de conversão: converte semanas em mês.
conv_periodo = 4
manut_periodo = 1

# Inicialização de totalizadores
val_alim_tot = 0
val_fruta_tot = 0
val_verd_tot = 0
val_bebe_tot = 0
val_prot_tot = 0

provisionamento = {
    "Provisiao_feira_frutas":150.00,
    "Provisao_feira_verduras":80.00,
    "Provisão Mercado": 2500.00
}

total_receitas = sum(provisionamento.values())

##############################################################################################
# 1 - Despesas com feira - frutas: R$ 178,50. 
##############################################################################################
despesas_frutas_semana = {"Abacate": 10.00, 
                          "Abacaxi": 12.00, 
                          "Banana":  15.00, 
                          "Caqui":   15.00,
                          "Kiwi":    12.00,
                          "Lar_Lima":06.00, 
                          "Lar Pera":12.00,
                          "Limão":   02.50,
                          "Macã ":   09.00, 
                          "Mamão":   15.00, 
                          "Melão":   30.00, 
                          "Ponkam":  005.00, 
                          "Pêra":    010.00,
                          "Uva":     25.00
}

# Calcular o valor das frutas compradas
total_frutas = sum(despesas_frutas_semana.values())

#########################################################
# Frutas ocasionais com montante estimado em (R$ 88.00)
#========================================================
# "Ameixa": 7.00,
# "Goiaba": 10.00, 
# "Manga": 10.00,
# "Melancia": 9.00,
# "Morango": 13.00,
# "Pêssego": 9.00,
# "Tâmara":10.00
#########################################################

########################################################
# 2 - Despesas com feira - verduras e legumes (R$ 160,00)
########################################################

despesas_verd_semana = {"Acelga": 8.00,
                        "Agrião": 4.00,
                        "Alface": 10.00,
                        "Escarola": 4.00,
                        "Espinafre": 4.00,
                        "Brócolis": 7.00,
                        "Abobora": 8.00,
                        "Abobrinha": 5.00,
                        "Cenoura": 3.00,
                        "mandioca": 8.00,
                        "Mandioquinha": 6.00,
                        "Tomate_molho": 25.00,
                        "Tomate_Salada": 10.00,
                        "Batata Doce": 8.00,
                        "Quiabo":5.00,
                        "Batata": 17.00,
                        "Alho": 18.00,
                        "Cebola Branca": 3.00,
                        "Cebola Roxa": 7.00
}

# Calcular o valor das verduras compradas
total_verduras = sum(despesas_verd_semana.values())



########################################################
# 3 - Despesas com supermercado - bebidas (R$ 714.99)
########################################################

desp_bebidas = {"Água sem gás": 22.00,
                        "Água com gás": 36.00,
                        "Leite_longa": 27.00,
                        "Suco de uva": 104.00,
                        "Café_Nesp": 360.00,
                        "Café Pilão": 139.60,
                        "Chás - Div": 26.39
                        
                        
}

total_bebidas = sum(desp_bebidas.values())

########################################################
# 4 - Despesas com supermercado - proteínas (R$ 265,80)
########################################################

desp_proteinas = {"contrafilé": 89.00,
                        "Miúdos_porco": 21.00,
                        "carne seca": 70.00,
                        "Linguiça": 15.00,
                        "Lombinho": 10.80,
                        "Óvos": 13.00,
                        "Carne_patinho": 16.00,
                        "Salsicha": 31.00
                        
}

total_proteinas = sum(desp_proteinas.values())

########################################################
# 5 - Despesas com supermercado - alimentos (R$ 900.35) 
########################################################

desp_alimentos = {"Áçúcar": 34.00,
                        "Adoçante": 22.98,
                        "Ameixa": 10.00,
                        "Amend Salg": 10.00,
                        "Arroz": 39.85,
                        "Aveia": 12.90,
                        "Azeite_Frit": 39.80,
                        "Azeite Sal": 145.80,
                        "Pão Baguete": 14.90,
                        "Batata Palha": 10.90,
                        "Barra de Choc": 21.68,
                        "Bisc. Pov":18.87,
                        "Bisc. - Div": 33.45,
                        "Bisc. Sam": 13.76,
                        "Bisc. Baud":29.90,
                        "Bisnaga": 7.79,
                        "Brioches": 37.33,
                        "Cereal - Mat": 11.79,
                        "Chia - grãos": 14.27,
                        "Chicletes":3.09,
                        "Creme_Leite": 7.99,
                        "Feijão": 6.79,
                        "Leite_Cond": 8.79,
                        "Macarrão": 5.99,
                        "Manteiga": 23.90,
                        "Mel Orgânico":24.90,
                        "Mortadela": 32.70,
                        "Óleo Girassol": 11.99,
                        "Pão de Forma": 15.90,
                        "Pão de Leite": 8.00,
                        "Pão Folhado": 9.59,
                        "Pão Francês": 14.81,
                        "Pão de Humb": 15.30,
                        "Papel Hig": 31.99,
                        "Queijo Frescal": 108.25,
                        "Queijo Parm": 15.83,
                        "Sal Refinado": 3.29,
                        "Torrada Baud": 5.49,
                        "Vinagre": 15.79                        
                        
}

total_alimentos = sum(desp_alimentos.values())

######################################################
# Rotina de cálculos
######################################################

# Calculando percentual de 
total_feira_semana = (total_frutas + total_verduras)

percent_feira_frutas = (total_frutas / total_receitas) * 100
percent_feira_verd = (total_verduras / total_receitas) * 100


# Elaboração do cálculo de percentuais dispendidos
Percent_frutas = (total_frutas / total_receitas) * 100
percent_verdur = (total_verduras / total_receitas) * 100

#################################################################################################
# 1 - Frutas: Rotina destinada a apresentação dos lançamentos mensais e dos cálculos efetuados
#################################################################################################
print("")
print("="* 106)
print("==================================== Feira semanal: Despesa com Frutas ===================================")
print("="* 106)

for item1, valor1 in despesas_frutas_semana.items():
    val_fruta1 = (conv_periodo * valor1)
    val_fruta_tot = valor1 + val_fruta_tot
    percent_frutas_sem = (val_fruta_tot / total_receitas) * 100
    percent_mes_frutas = ((val_fruta_tot * conv_periodo) / (total_receitas * conv_periodo) * 100)
    
    #print("-" * 106)
    print(f" {item1:15}: R$ {valor1:.2f}=======> Total_Mês R${val_fruta1:.2f} ==> \
    Perc. do gasto sobre provisão =====> {percent_frutas_sem:.2f}%")

print(" ")    
print(f" Total gasto com frutas = R${total_frutas:.2f} ")
############################################################################################
# 2 - Verduras: Rotina destinada a apresentação dos lançamentos mensais e dos cálculos efetuados
############################################################################################    
print("")
print("="* 110)
print("==================================== Feira semanal: Despesa com Verduras =====================================")
print("="* 110)

for item2, valor2 in despesas_verd_semana.items():
    val_verd2 = (conv_periodo * valor2)
    val_verd_tot = valor2 + val_verd_tot
    percent_verd2_sem = (val_verd2 / total_receitas) * 100
    percent_mes_verd = ((val_verd2 * conv_periodo) / (total_receitas * conv_periodo) * 100)
    
    #print("-" * 110)
    print(f" {item2:15}: R$ {valor2:.2f} ========> Total_Mês R${val_verd2:.2f} ==>\
    Perc. do gasto sobre provisão =======> {percent_verd2_sem:.2f}%")

print(" ")  
print(f" Total gasto com verduras = R${total_verduras:.2f} ")
#############################################################################################
# 3 - Bebidas: Rotina destinada a apresentação dos lançamentos mensais e dos cálculos efetuados
#############################################################################################    
print("")
print("="* 107)
print("==================================== Supermercado Mensal: Despesa com Bebidas =============================")
print("="* 107)

for item4, valor4 in desp_bebidas.items():
    val_bebe4 = (manut_periodo * valor4)
    val_bebe_tot = valor4 + val_bebe_tot
    percent_bebe_mes = (val_bebe_tot / total_receitas) * 100
    percent_bebe = ((val_bebe_tot * manut_periodo) / (total_receitas * manut_periodo) * 100)
    
    print("-" * 107)
    print(f" {item4:15}: R$ {valor4:.2f} ========> Total_Mês R${val_bebe4:.2f} ===>\
    Percent do gasto sobre provisão ===> {percent_bebe_mes:.2f}%")   
    
print(" ")  
print(f" Total gasto com bebidas = R${total_bebidas:.2f} ")
#############################################################################################
# 4 - Empório: Rotina destinada a apresentação dos lançamentos mensais e dos cálculos efetuados
#############################################################################################    

print("")
print("="* 107)
print("==================================== Supermercado Mensal: Despesa com empório =============================")
print("="* 107)

for item3, valor3 in desp_alimentos.items():
    val_alim3 = (manut_periodo * valor3)
    val_alim_tot = valor3 + val_alim_tot
    percent_Alim_mes = (val_alim_tot / total_receitas) * 100
    percent_alimento = ((val_alim_tot * manut_periodo) / (total_receitas * manut_periodo) * 100)
    
    #print("-" * 107)
    print(f" {item3:15}: R$ {valor3:.2f} ========> Total_Mês R${val_alim3:.2f} ===>\
    Percent do gasto sobre provisão ===> {percent_Alim_mes:.2f}%")
    
print(" ")  
print(f" Total gasto com emporio = R${total_alimentos:.2f} ")
#############################################################################################
# 5 - Proteínas: Rotina destinada a apresentação dos lançamentos mensais e dos cálculos efetuados
#############################################################################################    
print("")
print("="* 107)
print("==================================== Supermercado Mensal: Despesa com Proteínas ===========================")
print("="* 107)

for item5, valor5 in desp_proteinas.items():
    val_prot5 = (manut_periodo * valor5)
    val_prot_tot = valor5 + val_prot_tot
    percent_prote_mes = (val_prot_tot / total_receitas) * 100
    percent_prote = ((val_prot_tot * manut_periodo) / (total_receitas * manut_periodo) * 100)
    
    #print("-" * 107)
    print(f" {item5:15}: R$ {valor5:.2f} ========> Total_Mês R${val_prot5:.2f} ===>\
    Percent do gasto sobre provisão ===> {percent_prote_mes:.2f}%")

print(" ")  
print(f" Total gasto com proteinas = R${total_proteinas:.2f} ")
print("=" * 110)
print(" ")

#print("********************************* Despesas por situação ***************************************")

# 1 - Total das despesas com frutas
print(" ")
print("============================== Resumo das despesas por seguimento ===========================================")
print(" ")

print(f"Despesas com frutas:   R$ {total_frutas:.2f}  | Percent: gastos com frutas x Gasto totais: \
{Percent_frutas:.2f}%\n")
print("=" * 110)

# 2- Total das despesas com verduras
print(f"Despesas com verduras: R$ {total_verduras:.2f} | Percent: gastos com verduras x Gastos totais: \
{percent_verdur:.2f}%\n")
print("=" * 110)

# 3 - Total das despesas com bebidas
print(f"Despesas com bebidas: R$ {total_bebidas:.2f} | Percent: gastos com bebidas x Gastos totais: \
{percent_bebe:.2f}%\n")
print("=" * 110)

# 4 - Total das despesas com empório
print(f"Despesas com empório: R$ {total_alimentos:.2f} | Percent: gastos com empório x Gastos totais: \
{percent_alimento:.2f}%\n")
print("=" * 110)

# 5 - Total das despesas com proteínas
print(f"Despesas com proteínas: R$ {total_proteinas:.2f} | Percent: gastos com proteínas x Gastos totais: \
{percent_prote:.2f}%")

##############################################################################################
# Cálculo sobre o saldo provisionado após despesas do mês
#
##############################################################################################
saldo_final = (total_frutas + total_verduras + total_alimentos + total_bebidas + total_proteinas)
saldo_mes = (total_receitas - saldo_final)
percent_desp = (saldo_final / total_receitas) * 100
percent_resto = (100 - percent_desp)

#############################################################    
# Apresentação das totalizações dos lançamentos processados
#############################################################
print("")
print("=" * 110)
print(f"Provisão: ==> R${total_receitas:.2f} | Gastos Totais ==> R${saldo_final:.2f} ({percent_desp:.2f}%)| \
Restos do provisionamento: R${saldo_mes:.2f} ({percent_resto:.2f}%) ")
print("=" * 110)
# Out:
# ...
# ==================================== Feira semanal: Despesa com Frutas ===================================
# ...
#  Abacate        : R$ 10.00=======> Total_Mês R$40.00 ==>     Perc. do gasto sobre provisão =====> 0.37%
#  Abacaxi        : R$ 12.00=======> Total_Mês R$48.00 ==>     Perc. do gasto sobre provisão =====> 0.81%
#  Banana         : R$ 15.00=======> Total_Mês R$60.00 ==>     Perc. do gasto sobre provisão =====> 1.36%
#  Caqui          : R$ 15.00=======> Total_Mês R$60.00 ==>     Perc. do gasto sobre provisão =====> 1.90%
#  Kiwi           : R$ 12.00=======> Total_Mês R$48.00 ==>     Perc. do gasto sobre provisão =====> 2.34%
#  Lar_Lima       : R$ 6.00=======> Total_Mês R$24.00 ==>     Perc. do gasto sobre provisão =====> 2.56%
#  Lar Pera       : R$ 12.00=======> Total_Mês R$48.00 ==>     Perc. do gasto sobre provisão =====> 3.00%
#  Limão          : R$ 2.50=======> Total_Mês R$10.00 ==>     Perc. do gasto sobre provisão =====> 3.10%
# ...
